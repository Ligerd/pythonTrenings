# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class c1():
    a = 1
    b = 2
class c2():
    a = 'a'
    c = 'c'
class c11(c1, c2):
    def __init__(self,d):
        self.d = d

# %%
p = c11(2.3)
print(p.d, p.c, p.b, p.a)

# %%
s = c1()
s.a

# %%
s.b

# %%
s.c

# %%
t = c2()
t.c

# %%
class c1():
    _a = 1
    b = 2
class c2():
    a = 'a'
    c = 'c'
class c11(c1, c2):
    def __init__(self,d):
        self.d = d

# %%
p = c11(2.3)
print(p.d, p.c, p.b, p.a)

# %%
u = c1()
u._a
